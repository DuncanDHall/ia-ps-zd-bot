# %%
import datetime
import pickle
import datetime
from dateutil import parser
import requests
from requests.auth import HTTPBasicAuth
from os import environ as env
import imaplib
from email.parser import BytesParser
from email import policy
import re

import html2text

from zdbotutils import diff, mail
from zdbotutils.custom_logging import logger, logging
from config import *
from zdbotutils.mail import chunked

# %%
def epoch_time(d):
    epoch_start = parser.parse('1 Jan 1970 00:00:00 +0000 (UTC)')
    return int((d - epoch_start).total_seconds())

# %%
######################################################
# get updates in Zendesk (including suspended)
# TODO this vvv
since = None
if since:
    start_time = since
else:
#     start_time = epoch_time(datetime.datetime.now()) - 60 * 60 * 2  # 2 hours ago
#     start_time = 1608044094
    start_time = epoch_time(parser.parse('15 Dec 2020 01:00:00 +0000 (UTC)'))

# %%
url_template = 'https://archivesupport.zendesk.com/api/v2/incremental/ticket_events.json?start_time={}&include=comment_events'
next_page = url_template.format(start_time)
session = requests.session()

ticket_events = []
while True:
    logger.info('getting incremental ticket updates from Zendesk since {}'.format(start_time))
    response = session.get(
        next_page,
        auth=HTTPBasicAuth(env['ZENDESK_AGENT_ACCOUNT'] + "/token", env['ZENDESK_API_KEY'])
    )
    assert(response.status_code == 200), "{}: {}".format(response.status_code, response.content)
    data = response.json()
    ticket_events.extend(data['ticket_events'])
    
    if data['end_of_stream']:
        break
    next_page = data['next_page']
    start_time = data['end_time']
# Out:
# 2020-12-15 14:51:14,490 [INFO] <ipython-input-53-f2da3089cd73>:7 > getting incremental ticket updates from Zendesk since 1607994000
# 2020-12-15 14:51:38,711 [INFO] <ipython-input-53-f2da3089cd73>:7 > getting incremental ticket updates from Zendesk since 1607994000
# 2020-12-15 14:52:16,765 [INFO] <ipython-input-53-f2da3089cd73>:7 > getting incremental ticket updates from Zendesk since 1607994000

# %%
zendesk_comments = []  # [(timestamp, comment, ticket_id)...]
for event in ticket_events:
    contents_found = 0  # TODO ditch this variable
    for child in event['child_events']:
        if child['event_type'].lower() == 'comment':
            contents_found += 1
            if contents_found > 1:
                logger.error('found {} content children in single event'.format(contents_found))
            zendesk_comments.append((event['timestamp'], child['body'], event['ticket_id']))

# %%
######################################################
# get emails from support addresses
logger.info('getting archive support emails')
server = imaplib.IMAP4_SSL(host=IMAP_SERVER, port=IMAP_PORT)
server.login(env['DIFFBOT_ADDRESS'], env['DIFFBOT_PASSWORD'])
server.select(FROM_ARCHIVE_ACCOUNTS_FOLDER)
# Out:
# 2020-12-15 14:53:01,541 [INFO] <ipython-input-55-486bed08493b>:3 > getting archive support emails
# ('OK', [b'25443'])

# %%
# TODO status, response = server.search(None, 'ALL')
status, response = server.search(None, 'SINCE', '15-Dec-2020')
if status != 'OK':
    print('crap')
    exit(1)
# response of the form: [b'1 2 3 4']
if response[0] == b'':
    # TODO handle no emails to match against
    logger.error('no support emails to match against')

# %%
msg_ids = response[0].decode().split(' ')
logger.info('found {} support emails'.format(len(msg_ids)))
responses = []
for msg_ids_chunk in chunked(msg_ids, 1000):
    logger.debug('getting a message chunk')
    status, response = server.fetch(','.join(msg_ids_chunk), '(BODY[])')
    if status != 'OK':
        print('crap')
        exit(1)
    responses.extend(response)
server.logout()
# Out:
# 2020-12-15 14:53:20,147 [INFO] <ipython-input-57-dfb5e35e89ab>:2 > found 5374 support emails
# ('BYE', [b'Logging out'])

# %%
######################################################
# process emails so they are comparable with zendesk comments

# these configurations match what we get from zendesk
html2text.config.IGNORE_TABLES = True
html2text.config.IGNORE_IMAGES = False
h = html2text.HTML2Text()
h.ignore_links = True

# %%
# patterns and formats
# id_pattern = re.compile(b"(\d+) \(BODY\[\] \{\d+\}")
id_pattern = re.compile(b"(\d+).+")
time_str_format = '%a,  %d %b %Y %H:%M:%S %z (%Z)'

# %%
# collect decorated messages [(timestamp, comment, id)...]
support_msgs = []
logger.info('parsing archive support email data')
for li in responses:

    # weird case – something isn't implemented properly in the libraries
    if li == b')':
        continue

    id_bytes, msg_bytes = li
    msg = BytesParser(policy=policy.default).parsebytes(msg_bytes)

    # get id
    msg_id = int(re.match(id_pattern, id_bytes.strip()).group(1))
    logger.debug(id_bytes)
    logger.debug(msg_id)

    # get time stamp
    time_str = msg['Received'].split(';')[-1].strip()
    time_stamp = epoch_time(parser.parse(time_str))

    # get message body
    raw = msg.get_body(preferencelist=('plain',))
    if raw is None:
        raw = msg.get_body(preferencelist=('html',))
        if raw is None:
            logger.error('Found message with no plain or html body')
            continue
    try:
        html_content = raw.get_content()
    except LookupError as e:
        logger.error(e)
        continue
    body = h.handle(raw.get_content())

    support_msgs.append((time_stamp, body, msg_id))
# Out:
# 2020-12-15 15:05:40,683 [INFO] <ipython-input-61-d166e8f67667>:3 > parsing archive support email data
# 2020-12-15 15:06:20,298 [ERROR] <ipython-input-61-d166e8f67667>:32 > unknown encoding: iso-8859-8-i
# 2020-12-15 15:06:20,332 [ERROR] <ipython-input-61-d166e8f67667>:32 > unknown encoding: iso-8859-8-i

# %%
print(len(support_msgs))
# Out:
# 5372

# %%
import importlib
importlib.reload(diff)
# Out:
# <module 'zdbotutils.diff' from '/Users/duncanhall/Documents/work - IA/ia-ps-zd-bot/src/zdbotutils/diff.py'>

# %%
#######################################################
# match

# zendesk_comments = pickle.load(open("zendesk_comments.pickle", "rb"))
# support_msgs = pickle.load(open("support_msgs.pickle", "rb"))
# print(len(support_msgs))

logger.info('comment matching... (this could take a while)')
results = diff.match_msgs(zendesk_comments, support_msgs)
# pickle.dump(results, open('results.pickle', 'wb'))
# results = pickle.load(open('results.pickle', 'rb'))
zd_matched, zd_unmatched, archive_matched, archive_unmatched = results

with open('inspect.txt', 'w') as f:
    f.write('\nZD MATCHED\n')
    f.write(str(zd_matched))
    f.write('\nZD UNMATCHED\n')
    f.write(str(zd_unmatched))
    f.write('\nARCHIVE MATCHED\n')
    f.write(str(archive_matched))
    f.write('\nARCHIVE UNMATCHED\n')
    f.write(str(archive_unmatched))
print("zd_matched: {}/{}".format(len(zd_matched), len(zendesk_comments)))
print("zd_unmatched: {}".format(len(zd_unmatched)))
print("archive_matched: {}/{}".format(len(archive_matched), len(support_msgs)))
print("archive_unmatched: {}".format(len(archive_unmatched)))
# Out:
# 2020-12-15 15:37:26,747 [INFO] <ipython-input-83-40f1a8eec8ef>:8 > comment matching... (this could take a while)
# 2020-12-15 15:37:26,756 [INFO] diff.py:48 > Searching for match for item 0/1407
# 2020-12-15 15:37:26,911 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:26,914 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:27,490 [INFO] diff.py:48 > Searching for match for item 1/1407
# 2020-12-15 15:37:27,565 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:27,567 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:28,172 [INFO] diff.py:48 > Searching for match for item 2/1407
# 2020-12-15 15:37:28,389 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:28,391 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:28,842 [INFO] diff.py:48 > Searching for match for item 3/1407
# 2020-12-15 15:37:30,282 [INFO] diff.py:152 > full ratio: 0.9962 – "InternetArchiveNotificationofD..." and "InternetArchiveNotificationofD..." FULL MATCH
# 2020-12-15 15:37:30,285 [INFO] diff.py:152 > full ratio: 0.9962 – "InternetArchiveNotificationofD..." and "InternetArchiveNotificationofD..." FULL MATCH
# 2020-12-15 15:37:30,288 [INFO] diff.py:48 > Searching for match for item 4/1407
# 2020-12-15 15:37:30,291 [INFO] diff.py:152 > full ratio: 0.9962 – "InternetArchiveNotificationofD..." and "InternetArchiveNotificationofD..." FULL MATCH
# 2020-12-15 15:37:30,293 [INFO] diff.py:152 > full ratio: 0.9962 – "InternetArchiveNotificationofD..." and "InternetArchiveNotificationofD..." FULL MATCH
# 2020-12-15 15:37:32,832 [INFO] diff.py:48 > Searching for match for item 5/1407
# 2020-12-15 15:37:33,306 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:33,309 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:33,667 [INFO] diff.py:48 > Searching for match for item 6/1407
# 2020-12-15 15:37:34,202 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:34,204 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:34,689 [INFO] diff.py:48 > Searching for match for item 7/1407
# 2020-12-15 15:37:35,362 [INFO] diff.py:152 > full ratio: 0.9967 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:35,365 [INFO] diff.py:152 > full ratio: 0.9967 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:36,454 [INFO] diff.py:48 > Searching for match for item 8/1407
# 2020-12-15 15:37:36,966 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:36,969 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:37,422 [INFO] diff.py:48 > Searching for match for item 9/1407
# 2020-12-15 15:37:38,012 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:38,015 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:38,440 [INFO] diff.py:48 > Searching for match for item 10/1407
# 2020-12-15 15:37:38,784 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:38,787 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:39,142 [INFO] diff.py:48 > Searching for match for item 11/1407
# 2020-12-15 15:37:39,802 [INFO] diff.py:152 > full ratio: 0.9967 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:39,805 [INFO] diff.py:152 > full ratio: 0.9967 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:40,204 [INFO] diff.py:48 > Searching for match for item 12/1407
# 2020-12-15 15:37:40,761 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:40,764 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:41,004 [INFO] diff.py:48 > Searching for match for item 13/1407
# 2020-12-15 15:37:41,466 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:41,469 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:41,784 [INFO] diff.py:48 > Searching for match for item 14/1407
# 2020-12-15 15:37:42,429 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:42,432 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:42,592 [INFO] diff.py:48 > Searching for match for item 15/1407
# 2020-12-15 15:37:43,079 [INFO] diff.py:152 > full ratio: 0.9967 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:43,082 [INFO] diff.py:152 > full ratio: 0.9967 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:43,645 [INFO] diff.py:48 > Searching for match for item 16/1407
# 2020-12-15 15:37:43,811 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:43,813 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:44,095 [INFO] diff.py:48 > Searching for match for item 17/1407
# 2020-12-15 15:37:44,247 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37:44,249 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:37
[INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:38:32,555 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:38:32,923 [INFO] diff.py:48 > Searching for match for item 118/1407
# 2020-12-15 15:38:32,978 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:38:32,981 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:38:33,799 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:33,800 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:33,975 [INFO] diff.py:48 > Searching for match for item 119/1407
# 2020-12-15 15:38:34,101 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:38:34,103 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:38:34,908 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:34,909 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:35,576 [INFO] diff.py:48 > Searching for match for item 120/1407
# 2020-12-15 15:38:35,738 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:38:35,741 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:38:36,448 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:36,449 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:37,090 [INFO] diff.py:48 > Searching for match for item 121/1407
# 2020-12-15 15:38:37,300 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:38:37,302 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:38:37,977 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:37,978 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:38,615 [INFO] diff.py:48 > Searching for match for item 122/1407
# 2020-12-15 15:38:39,278 [INFO] diff.py:152 > full ratio: 0.9967 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:38:39,281 [INFO] diff.py:152 > full ratio: 0.9967 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:38:40,008 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:40,009 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:40,682 [INFO] diff.py:48 > Searching for match for item 123/1407
# 2020-12-15 15:38:41,042 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:38:41,045 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:38:41,513 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:41,514 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:42,131 [INFO] diff.py:48 > Searching for match for item 124/1407
# 2020-12-15 15:38:44,800 [INFO] diff.py:152 > full ratio: 0.9963 – "InternetArchiveNotificationofD..." and "InternetArchiveNotificationofD..." FULL MATCH
# 2020-12-15 15:38:44,802 [INFO] diff.py:152 > full ratio: 0.9963 – "InternetArchiveNotificationofD..." and "InternetArchiveNotificationofD..." FULL MATCH
# 2020-12-15 15:38:44,803 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:44,804 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,054 [INFO] diff.py:48 > Searching for match for item 125/1407
# 2020-12-15 15:38:46,055 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,055 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,056 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,057 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,057 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,058 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,059 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,059 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,059 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,060 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,061 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,061 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,061 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,062 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,062 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,063 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,063 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,064 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,064 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,065 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,065 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,066 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,067 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,067 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,067 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,068 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,068 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,069 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,069 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,070 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,070 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,071 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,071 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,072 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,072 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,073 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,073 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,074 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,076 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,076 [INFO] diff.py:48 > Searching for match for item 126/1407
# 2020-12-15 15:38:46,086 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,086 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:46,095 [INFO] diff.py:48 > Searching for match for item 127/1407
# 2020-12-15 15:38:47,411 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:47,412 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:47,415 [INFO] diff.py:152 > full ratio: 0.9967 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:38:47,417 [INFO] diff.py:152 > full ratio: 0.9967 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:38:48,070 [INFO] diff.py:48 > Searching for match for item 128/1407
# 2020-12-15 15:38:50,316 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:50,316 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:50,905 [INFO] diff.py:152 > full ratio: 0.9963 – "InternetArchiveNotificationofD..." and "InternetArchiveNotificationofD..." FULL MATCH
# 2020-12-15 15:38:50,908 [INFO] diff.py:152 > full ratio: 0.9963 – "InternetArchiveNotificationofD..." and "InternetArchiveNotificationofD..." FULL MATCH
# 2020-12-15 15:38:51,555 [INFO] diff.py:48 > Searching for match for item 129/1407
# 2020-12-15 15:38:51,564 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:51,565 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:51,585 [INFO] diff.py:48 > Searching for match for item 130/1407
# 2020-12-15 15:38:51,590 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:51,591 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:51,595 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:51,596 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:51,596 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:51,597 [INFO] diff.py:129 > COMPLETE MATCH
# 2020-12-15 15:38:51,601 [INFO] diff.py:48 > Searching for match for item 131/1407
# 2020-12-15 15:38:52,330 [INFO] diff.py:152 > full ratio: 0.9967 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:38
[INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:48:44,831 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:48:45,340 [INFO] diff.py:48 > Searching for match for item 1401/1407
# 2020-12-15 15:48:45,357 [INFO] diff.py:48 > Searching for match for item 1402/1407
# 2020-12-15 15:48:45,441 [INFO] diff.py:48 > Searching for match for item 1403/1407
# 2020-12-15 15:48:45,456 [INFO] diff.py:48 > Searching for match for item 1404/1407
# 2020-12-15 15:48:45,488 [INFO] diff.py:48 > Searching for match for item 1405/1407
# 2020-12-15 15:48:45,825 [INFO] diff.py:152 > full ratio: 0.9967 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:48:45,828 [INFO] diff.py:152 > full ratio: 0.9967 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:48:46,620 [INFO] diff.py:48 > Searching for match for item 1406/1407
# 2020-12-15 15:48:46,869 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# 2020-12-15 15:48:46,871 [INFO] diff.py:152 > full ratio: 0.9966 – "InternetArchiveherearethedetai..." and "InternetArchiveherearethedetai..." FULL MATCH
# zd_matched: 1087/1407
# zd_unmatched: 319
# archive_matched: 703/5372
# archive_unmatched: 4624

# %%
server = imaplib.IMAP4_SSL(host=IMAP_SERVER, port=IMAP_PORT)
server.login(env['DIFFBOT_ADDRESS'], env['DIFFBOT_PASSWORD'])
server.select(FROM_ARCHIVE_ACCOUNTS_FOLDER)
# Out:
# ('OK', [b'27151'])

# %%
#######################################################
# move matched emails
archive_matched_ids = [str(msg_id) for _, _, msg_id in archive_matched]
logger.info('moving {} matched emails'.format(len(archive_matched_ids)))
for msg_ids_chunk in chunked(archive_matched_ids, 1000):
    ids = ','.join(msg_ids_chunk)
    logger.debug(ids)
    server.copy(ids, MATCHED_ARCHIVE_FOLDER)
    server.store(ids, '+FLAGS', '\\Deleted')
server.expunge()
# Out:
# 2020-12-15 16:21:05,888 [INFO] <ipython-input-100-7fa4f764f74d>:4 > moving 703 matched emails
# ('OK',
#  [b'25398',
#   b'25371',
#   b'25334',
#   b'25332',
#   b'25328',
#   b'25320',
#   b'25316',
#   b'25312',
#   b'25302',
#   b'25290',
#   b'25254',
#   b'25252',
#   b'25232',
#   b'25230',
#   b'25226',
#   b'25221',
#   b'25210',
#   b'25201',
#   b'25196',
#   b'25191',
#   b'25179',
#   b'25177',
#   b'25172',
#   b'25171',
#   b'25161',
#   b'25159',
#   b'25149',
#   b'25147',
#   b'25142',
#   b'25123',
#   b'25122',
#   b'25119',
#   b'25117',
#   b'25108',
#   b'25099',
#   b'25088',
#   b'25082',
#   b'25079',
#   b'25065',
#   b'25057',
#   b'25036',
#   b'25013',
#   b'25007',
#   b'24965',
#   b'24932',
#   b'24925',
#   b'24903',
#   b'24900',
#   b'24891',
#   b'24886',
#   b'24869',
#   b'24866',
#   b'24847',
#   b'24841',
#   b'24837',
#   b'24821',
#   b'24815',
#   b'24808',
#   b'24801',
#   b'24797',
#   b'24792',
#   b'24787',
#   b'24782',
#   b'24768',
#   b'24766',
#   b'24765',
#   b'24759',
#   b'24751',
#   b'24562',
#   b'24559',
#   b'24556',
#   b'24553',
#   b'24551',
#   b'24549',
#   b'24545',
#   b'24536',
#   b'24530',
#   b'24529',
#   b'24525',
#   b'24520',
#   b'24518',
#   b'24514',
#   b'24513',
#   b'24512',
#   b'24509',
#   b'24507',
#   b'24502',
#   b'24499',
#   b'24497',
#   b'24491',
#   b'24484',
#   b'24478',
#   b'24477',
#   b'24475',
#   b'24471',
#   b'24457',
#   b'24453',
#   b'24450',
#   b'24447',
#   b'24442',
#   b'24440',
#   b'24432',
#   b'24423',
#   b'24420',
#   b'24408',
#   b'24405',
#   b'24404',
#   b'24401',
#   b'24399',
#   b'24388',
#   b'24387',
#   b'24385',
#   b'24384',
#   b'24378',
#   b'24371',
#   b'24368',
#   b'24362',
#   b'24356',
#   b'24352',
#   b'24351',
#   b'24343',
#   b'24333',
#   b'24331',
#   b'24320',
#   b'24319',
#   b'24318',
#   b'24316',
#   b'24315',
#   b'24314',
#   b'24313',
#   b'24302',
#   b'24301',
#   b'24300',
#   b'24293',
#   b'24281',
#   b'24279',
#   b'24272',
#   b'24266',
#   b'24264',
#   b'24255',
#   b'24253',
#   b'24249',
#   b'24247',
#   b'24246',
#   b'24239',
#   b'24232',
#   b'24230',
#   b'24222',
#   b'24213',
#   b'24179',
#   b'24178',
#   b'24176',
#   b'23934',
#   b'23932',
#   b'23931',
#   b'23929',
#   b'23923',
#   b'23922',
#   b'23914',
#   b'23911',
#   b'23909',
#   b'23904',
#   b'23903',
#   b'23899',
#   b'23898',
#   b'23889',
#   b'23884',
#   b'23880',
#   b'23879',
#   b'23876',
#   b'23873',
#   b'23872',
#   b'23871',
#   b'23870',
#   b'23864',
#   b'23863',
#   b'23861',
#   b'23855',
#   b'23853',
#   b'23850',
#   b'23844',
#   b'23834',
#   b'23830',
#   b'23829',
#   b'23821',
#   b'23817',
#   b'23816',
#   b'23814',
#   b'23813',
#   b'23806',
#   b'23805',
#   b'23804',
#   b'23803',
#   b'23783',
#   b'23777',
#   b'23768',
#   b'23765',
#   b'23764',
#   b'23761',
#   b'23758',
#   b'23755',
#   b'23749',
#   b'23740',
#   b'23727',
#   b'23726',
#   b'23719',
#   b'23715',
#   b'23710',
#   b'23706',
#   b'23705',
#   b'23703',
#   b'23702',
#   b'23695',
#   b'23693',
#   b'23681',
#   b'23680',
#   b'23679',
#   b'23668',
#   b'23666',
#   b'23665',
#   b'23660',
#   b'23659',
#   b'23658',
#   b'23655',
#   b'23654',
#   b'23653',
#   b'23646',
#   b'23637',
#   b'23636',
#   b'23633',
#   b'23622',
#   b'23618',
#   b'23617',
#   b'23609',
#   b'23607',
#   b'23603',
#   b'23602',
#   b'23601',
#   b'23599',
#   b'23598',
#   b'23594',
#   b'23591',
#   b'23589',
#   b'23588',
#   b'23582',
#   b'23574',
#   b'23567',
#   b'23558',
#   b'23554',
#   b'21924',
#   b'21921',
#   b'21917',
#   b'21909',
#   b'21903',
#   b'21899',
#   b'21898',
#   b'21897',
#   b'21894',
#   b'21891',
#   b'21888',
#   b'21885',
#   b'21883',
#   b'21881',
#   b'21876',
#   b'21873',
#   b'21869',
#   b'21864',
#   b'21863',
#   b'21862',
#   b'21852',
#   b'21846',
#   b'21844',
#   b'21840',
#   b'21837',
#   b'21829',
#   b'21826',
#   b'21817',
#   b'21813',
#   b'21812',
#   b'21811',
#   b'21810',
#   b'21800',
#   b'21795',
#   b'21794',
#   b'21791',
#   b'21784',
#   b'21783',
#   b'21782',
#   b'21780',
#   b'21769',
#   b'21768',
#   b'21766',
#   b'21764',
#   b'21763',
#   b'21759',
#   b'21750',
#   b'21749',
#   b'21744',
#   b'21743',
#   b'21742',
#   b'21741',
#   b'21739',
#   b'21727',
#   b'21722',
#   b'21721',
#   b'21718',
#   b'21715',
#   b'21709',
#   b'21708',
#   b'21705',
#   b'21696',
#   b'21695',
#   b'21689',
#   b'21687',
#   b'21686',
#   b'21685',
#   b'21684',
#   b'21678',
#   b'21676',
#   b'21672',
#   b'21669',
#   b'21668',
#   b'21667',
#   b'21666',
#   b'21663',
#   b'21657',
#   b'21655',
#   b'21653',
#   b'21651',
#   b'21644',
#   b'21642',
#   b'21638',
#   b'21635',
#   b'21633',
#   b'21628',
#   b'21624',
#   b'21619',
#   b'21617',
#   b'21613',
#   b'21611',
#   b'21606',
#   b'21605',
#   b'21601',
#   b'21600',
#   b'21599',
#   b'21598',
#   b'21579',
#   b'21573',
#   b'21572',
#   b'21571',
#   b'21569',
#   b'21555',
#   b'21549',
#   b'21543',
#   b'21541',
#   b'21538',
#   b'21534',
#   b'21533',
#   b'21530',
#   b'21526',
#   b'21521',
#   b'21517',
#   b'21515',
#   b'21513',
#   b'21512',
#   b'21511',
#   b'21510',
#   b'21506',
#   b'21503',
#   b'21499',
#   b'21490',
#   b'21489',
#   b'21486',
#   b'21485',
#   b'21478',
#   b'21470',
#   b'21469',
#   b'21467',
#   b'21458',
#   b'21455',
#   b'21453',
#   b'21450',
#   b'21448',
#   b'21443',
#   b'21439',
#   b'21437',
#   b'21434',
#   b'21433',
#   b'21431',
#   b'21429',
#   b'21423',
#   b'21422',
#   b'21419',
#   b'21418',
#   b'21410',
#   b'21408',
#   b'21405',
#   b'21394',
#   b'21378',
#   b'21376',
#   b'21372',
#   b'21371',
#   b'21370',
#   b'21288',
#   b'21279',
#   b'21275',
#   b'21274',
#   b'21272',
#   b'21271',
#   b'21267',
#   b'21266',
#   b'21264',
#   b'21247',
#   b'21243',
#   b'21241',
#   b'21239',
#   b'21238',
#   b'21236',
#   b'21235',
#   b'21234',
#   b'21233',
#   b'21225',
#   b'21220',
#   b'21218',
#   b'21217',
#   b'21211',
#   b'21210',
#   b'21208',
#   b'21203',
#   b'21199',
#   b'21192',
#   b'21190',
#   b'21189',
#   b'21170',
#   b'21165',
#   b'21150',
#   b'21149',
#   b'21148',
#   b'21147',
#   b'21145',
#   b'21138',
#   b'21133',
#   b'21130',
#   b'21128',
#   b'21125',
#   b'21111',
#   b'21106',
#   b'21104',
#   b'21103',
#   b'21100',
#   b'21098',
#   b'21094',
#   b'21089',
#   b'21087',
#   b'21084',
#   b'21081',
#   b'21068',
#   b'21065',
#   b'21064',
#   b'21062',
#   b'21051',
#   b'21050',
#   b'21048',
#   b'21036',
#   b'21030',
#   b'21028',
#   b'21026',
#   b'21017',
#   b'21015',
#   b'21008',
#   b'21003',
#   b'20993',
#   b'20988',
#   b'20984',
#   b'20981',
#   b'20972',
#   b'20970',
#   b'20965',
#   b'20964',
#   b'20960',
#   b'20959',
#   b'20938',
#   b'20937',
#   b'20936',
#   b'20934',
#   b'20928',
#   b'20924',
#   b'20909',
#   b'20901',
#   b'20892',
#   b'20889',
#   b'20885',
#   b'20883',
#   b'20874',
#   b'20870',
#   b'20867',
#   b'20859',
#   b'20856',
#   b'20855',
#   b'20851',
#   b'20848',
#   b'20846',
#   b'20844',
#   b'20842',
#   b'20840',
#   b'20837',
#   b'20827',
#   b'20825',
#   b'20824',
#   b'20819',
#   b'20818',
#   b'20817',
#   b'20816',
#   b'20806',
#   b'20804',
#   b'20789',
#   b'20783',
#   b'20776',
#   b'20772',
#   b'20767',
#   b'20765',
#   b'20762',
#   b'20759',
#   b'20755',
#   b'20744',
#   b'20742',
#   b'20730',
#   b'20729',
#   b'20727',
#   b'20722',
#   b'20711',
#   b'20709',
#   b'20702',
#   b'20694',
#   b'20692',
#   b'20689',
#   b'20670',
#   b'20669',
#   b'20662',
#   b'20660',
#   b'20657',
#   b'20656',
#   b'20641',
#   b'20639',
#   b'20635',
#   b'20633',
#   b'20619',
#   b'20612',
#   b'20611',
#   b'20609',
#   b'20607',
#   b'20603',
#   b'20593',
#   b'20592',
#   b'20591',
#   b'20589',
#   b'20587',
#   b'20586',
#   b'20584',
#   b'20583',
#   b'20581',
#   b'20568',
#   b'20565',
#   b'20563',
#   b'20561',
#   b'20549',
#   b'20531',
#   b'20518',
#   b'20501',
#   b'20496',
#   b'20492',
#   b'20489',
#   b'20487',
#   b'20486',
#   b'20483',
#   b'20480',
#   b'20474',
#   b'20473',
#   b'20466',
#   b'20461',
#   b'20456',
#   b'20453',
#   b'20450',
#   b'20448',
#   b'20447',
#   b'20445',
#   b'20444',
#   b'20442',
#   b'20435',
#   b'20434',
#   b'20432',
#   b'20429',
#   b'20428',
#   b'20426',
#   b'20420',
#   b'20416',
#   b'20414',
#   b'20406',
#   b'20403',
#   b'20401',
#   b'20397',
#   b'20389',
#   b'20383',
#   b'20379',
#   b'20377',
#   b'20376',
#   b'20374',
#   b'20373',
#   b'20372',
#   b'20371',
#   b'20362',
#   b'20360',
#   b'20358',
#   b'20354',
#   b'20353',
#   b'20348',
#   b'20334',
#   b'20329',
#   b'20328',
#   b'20326',
#   b'20325',
#   b'20323',
#   b'20322',
#   b'20321',
#   b'20315',
#   b'20304',
#   b'20302',
#   b'20296',
#   b'20292',
#   b'20286',
#   b'20283',
#   b'20280',
#   b'20277',
#   b'20274',
#   b'20267',
#   b'20261',
#   b'20258',
#   b'20249',
#   b'20247',
#   b'20218',
#   b'20217',
#   b'20215',
#   b'20214',
#   b'20206',
#   b'20203',
#   b'20198',
#   b'20196',
#   b'20192',
#   b'20190',
#   b'20186',
#   b'20184',
#   b'20183',
#   b'20180',
#   b'20174',
#   b'20172',
#   b'20168',
#   b'20166',
#   b'20164',
#   b'20160',
#   b'20159',
#   b'20157',
#   b'20154',
#   b'20141',
#   b'20132',
#   b'20131',
#   b'20130',
#   b'20127',
#   b'20118',
#   b'20110',
#   b'20108',
#   b'20107',
#   b'20097',
#   b'20094',
#   b'20092',
#   b'20078',
#   b'20076',
#   b'20065',
#   b'20058',
#   b'20055',
#   b'20049',
#   b'20036',
#   b'20030',
#   b'20028',
#   b'20026',
#   b'20025',
#   b'20019',
#   b'20015',
#   b'20010',
#   b'20003',
#   b'19997',
#   b'19996',
#   b'19995',
#   b'19992',
#   b'19991',
#   b'19990',
#   b'19980',
#   b'19976',
#   b'19966',
#   b'19963',
#   b'19957',
#   b'19956',
#   b'19944',
#   b'19941'])

# %%
#######################################################
# log old unmatched ticket comments
cutoff = datetime.datetime.now().timestamp() - MINUTES_GRACE_PERIOD * 60
old_zd_unmatched = {(t, c, ticket_id) for t, c, ticket_id in zd_unmatched if t < cutoff}
logger.info('logging {} old unmatched zendesk comments'.format(len(old_zd_unmatched)))
with open('zd_unmatched_log.txt', 'w') as f:
    for t, c, t_id in old_zd_unmatched:
        f.write("""
Ticket #{}
Time: {}
Comment:
{}
        """.format(t_id, str(datetime.datetime.fromtimestamp(t)), c))
# Out:
# 2020-12-15 16:21:10,071 [INFO] <ipython-input-101-a4c93ff4325c>:5 > logging 319 old unmatched zendesk comments

# %%
#######################################################
# move old emails to unmatched
cutoff = datetime.datetime.now().timestamp() - MINUTES_GRACE_PERIOD * 60
old_archive_unmatched_ids = [str(msg_id) for t, _, msg_id in archive_unmatched if t < cutoff]
logger.info('moving {} old unmatched archive emails'.format(len(old_archive_unmatched_ids)))
for msg_ids_chunk in chunked(old_archive_unmatched_ids, 1000):
    ids = ','.join(msg_ids_chunk)
    server.copy(ids, UNMATCHED_ARCHIVE_FOLDER)
    server.store(ids, '+FLAGS', '\\Deleted')
server.expunge()
# Out:
# 2020-12-15 16:21:12,055 [INFO] <ipython-input-102-4869ecdbfc07>:5 > moving 4624 old unmatched archive emails
# ('OK',
#  [b'25397',
#   b'25396',
#   b'25395',
#   b'25394',
#   b'25393',
#   b'25392',
#   b'25391',
#   b'25390',
#   b'25389',
#   b'25388',
#   b'25387',
#   b'25386',
#   b'25385',
#   b'25384',
#   b'25383',
#   b'25382',
#   b'25381',
#   b'25380',
#   b'25379',
#   b'25378',
#   b'25377',
#   b'25376',
#   b'25375',
#   b'25374',
#   b'25373',
#   b'25372',
#   b'25370',
#   b'25369',
#   b'25368',
#   b'25367',
#   b'25366',
#   b'25365',
#   b'25364',
#   b'25363',
#   b'25362',
#   b'25361',
#   b'25360',
#   b'25359',
#   b'25358',
#   b'25357',
#   b'25356',
#   b'25355',
#   b'25354',
#   b'25353',
#   b'25352',
#   b'25351',
#   b'25350',
#   b'25349',
#   b'25348',
#   b'25347',
#   b'25346',
#   b'25345',
#   b'25344',
#   b'25343',
#   b'25342',
#   b'25341',
#   b'25340',
#   b'25339',
#   b'25338',
#   b'25337',
#   b'25336',
#   b'25335',
#   b'25333',
#   b'25331',
#   b'25330',
#   b'25329',
#   b'25327',
#   b'25326',
#   b'25325',
#   b'25324',
#   b'25323',
#   b'25322',
#   b'25321',
#   b'25319',
#   b'25318',
#   b'25317',
#   b'25315',
#   b'25314',
#   b'25313',
#   b'25311',
#   b'25310',
#   b'25309',
#   b'25308',
#   b'25307',
#   b'25306',
#   b'25305',
#   b'25304',
#   b'25303',
#   b'25301',
#   b'25300',
#   b'25299',
#   b'25298',
#   b'25297',
#   b'25296',
#   b'25295',
#   b'25294',
#   b'25293',
#   b'25292',
#   b'25291',
#   b'25289',
#   b'25288',
#   b'25287',
#   b'25286',
#   b'25285',
#   b'25284',
#   b'25283',
#   b'25282',
#   b'25281',
#   b'25280',
#   b'25279',
#   b'25278',
#   b'25277',
#   b'25276',
#   b'25275',
#   b'25274',
#   b'25273',
#   b'25272',
#   b'25271',
#   b'25270',
#   b'25269',
#   b'25268',
#   b'25267',
#   b'25266',
#   b'25265',
#   b'25264',
#   b'25263',
#   b'25262',
#   b'25261',
#   b'25260',
#   b'25259',
#   b'25258',
#   b'25257',
#   b'25256',
#   b'25255',
#   b'25253',
#   b'25251',
#   b'25250',
#   b'25249',
#   b'25248',
#   b'25247',
#   b'25246',
#   b'25245',
#   b'25244',
#   b'25243',
#   b'25242',
#   b'25241',
#   b'25240',
#   b'25239',
#   b'25238',
#   b'25237',
#   b'25236',
#   b'25235',
#   b'25234',
#   b'25233',
#   b'25231',
#   b'25229',
#   b'25228',
#   b'25227',
#   b'25225',
#   b'25224',
#   b'25223',
#   b'25222',
#   b'25220',
#   b'25219',
#   b'25218',
#   b'25217',
#   b'25216',
#   b'25215',
#   b'25214',
#   b'25213',
#   b'25212',
#   b'25211',
#   b'25209',
#   b'25208',
#   b'25207',
#   b'25206',
#   b'25205',
#   b'25204',
#   b'25203',
#   b'25202',
#   b'25200',
#   b'25199',
#   b'25198',
#   b'25197',
#   b'25195',
#   b'25194',
#   b'25193',
#   b'25192',
#   b'25190',
#   b'25189',
#   b'25188',
#   b'25187',
#   b'25186',
#   b'25185',
#   b'25184',
#   b'25183',
#   b'25182',
#   b'25181',
#   b'25180',
#   b'25178',
#   b'25176',
#   b'25175',
#   b'25174',
#   b'25173',
#   b'25170',
#   b'25169',
#   b'25168',
#   b'25167',
#   b'25166',
#   b'25165',
#   b'25164',
#   b'25163',
#   b'25162',
#   b'25160',
#   b'25158',
#   b'25157',
#   b'25156',
#   b'25155',
#   b'25154',
#   b'25153',
#   b'25151',
#   b'25150',
#   b'25148',
#   b'25145',
#   b'25144',
#   b'25143',
#   b'25141',
#   b'25140',
#   b'25139',
#   b'25138',
#   b'25137',
#   b'25136',
#   b'25135',
#   b'25134',
#   b'25133',
#   b'25132',
#   b'25131',
#   b'25130',
#   b'25129',
#   b'25128',
#   b'25127',
#   b'25126',
#   b'25125',
#   b'25124',
#   b'25121',
#   b'25120',
#   b'25118',
#   b'25116',
#   b'25115',
#   b'25114',
#   b'25113',
#   b'25112',
#   b'25111',
#   b'25110',
#   b'25109',
#   b'25107',
#   b'25106',
#   b'25105',
#   b'25104',
#   b'25103',
#   b'25102',
#   b'25101',
#   b'25100',
#   b'25098',
#   b'25097',
#   b'25096',
#   b'25095',
#   b'25094',
#   b'25093',
#   b'25092',
#   b'25091',
#   b'25090',
#   b'25089',
#   b'25087',
#   b'25086',
#   b'25085',
#   b'25084',
#   b'25083',
#   b'25081',
#   b'25080',
#   b'25078',
#   b'25077',
#   b'25076',
#   b'25075',
#   b'25074',
#   b'25073',
#   b'25072',
#   b'25071',
#   b'25070',
#   b'25069',
#   b'25068',
#   b'25067',
#   b'25066',
#   b'25064',
#   b'25063',
#   b'25062',
#   b'25061',
#   b'25060',
#   b'25059',
#   b'25058',
#   b'25056',
#   b'25055',
#   b'25054',
#   b'25053',
#   b'25052',
#   b'25051',
#   b'25050',
#   b'25049',
#   b'25048',
#   b'25047',
#   b'25046',
#   b'25045',
#   b'25044',
#   b'25043',
#   b'25042',
#   b'25041',
#   b'25040',
#   b'25039',
#   b'25038',
#   b'25037',
#   b'25035',
#   b'25034',
#   b'25033',
#   b'25032',
#   b'25031',
#   b'25030',
#   b'25029',
#   b'25028',
#   b'25027',
#   b'25026',
#   b'25025',
#   b'25024',
#   b'25023',
#   b'25022',
#   b'25021',
#   b'25020',
#   b'25019',
#   b'25018',
#   b'25017',
#   b'25016',
#   b'25015',
#   b'25014',
#   b'25012',
#   b'25011',
#   b'25010',
#   b'25009',
#   b'25008',
#   b'25006',
#   b'25005',
#   b'25004',
#   b'25003',
#   b'25002',
#   b'25001',
#   b'25000',
#   b'24999',
#   b'24998',
#   b'24997',
#   b'24996',
#   b'24995',
#   b'24994',
#   b'24993',
#   b'24992',
#   b'24991',
#   b'24990',
#   b'24989',
#   b'24988',
#   b'24987',
#   b'24986',
#   b'24985',
#   b'24984',
#   b'24983',
#   b'24982',
#   b'24981',
#   b'24980',
#   b'24979',
#   b'24978',
#   b'24977',
#   b'24976',
#   b'24975',
#   b'24974',
#   b'24973',
#   b'24972',
#   b'24971',
#   b'24970',
#   b'24969',
#   b'24968',
#   b'24967',
#   b'24966',
#   b'24964',
#   b'24963',
#   b'24962',
#   b'24961',
#   b'24960',
#   b'24959',
#   b'24958',
#   b'24957',
#   b'24956',
#   b'24955',
#   b'24954',
#   b'24953',
#   b'24952',
#   b'24951',
#   b'24950',
#   b'24949',
#   b'24948',
#   b'24947',
#   b'24946',
#   b'24945',
#   b'24944',
#   b'24943',
#   b'24942',
#   b'24941',
#   b'24940',
#   b'24939',
#   b'24938',
#   b'24937',
#   b'24936',
#   b'24935',
#   b'24934',
#   b'24933',
#   b'24931',
#   b'24930',
#   b'24929',
#   b'24928',
#   b'24927',
#   b'24926',
#   b'24924',
#   b'24923',
#   b'24922',
#   b'24921',
#   b'24920',
#   b'24919',
#   b'24918',
#   b'24917',
#   b'24916',
#   b'24915',
#   b'24914',
#   b'24913',
#   b'24912',
#   b'24911',
#   b'24910',
#   b'24909',
#   b'24908',
#   b'24907',
#   b'24906',
#   b'24905',
#   b'24904',
#   b'24902',
#   b'24901',
#   b'24899',
#   b'24898',
#   b'24897',
#   b'24896',
#   b'24895',
#   b'24894',
#   b'24893',
#   b'24892',
#   b'24890',
#   b'24889',
#   b'24888',
#   b'24887',
#   b'24885',
#   b'24884',
#   b'24883',
#   b'24882',
#   b'24881',
#   b'24880',
#   b'24879',
#   b'24878',
#   b'24877',
#   b'24876',
#   b'24875',
#   b'24874',
#   b'24873',
#   b'24872',
#   b'24871',
#   b'24870',
#   b'24868',
#   b'24867',
#   b'24865',
#   b'24864',
#   b'24863',
#   b'24862',
#   b'24861',
#   b'24860',
#   b'24859',
#   b'24858',
#   b'24857',
#   b'24856',
#   b'24855',
#   b'24854',
#   b'24853',
#   b'24852',
#   b'24851',
#   b'24850',
#   b'24849',
#   b'24848',
#   b'24846',
#   b'24845',
#   b'24844',
#   b'24843',
#   b'24842',
#   b'24840',
#   b'24839',
#   b'24838',
#   b'24836',
#   b'24835',
#   b'24834',
#   b'24833',
#   b'24832',
#   b'24831',
#   b'24830',
#   b'24829',
#   b'24828',
#   b'24827',
#   b'24826',
#   b'24825',
#   b'24824',
#   b'24823',
#   b'24822',
#   b'24820',
#   b'24819',
#   b'24818',
#   b'24817',
#   b'24816',
#   b'24814',
#   b'24813',
#   b'24812',
#   b'24811',
#   b'24810',
#   b'24809',
#   b'24807',
#   b'24806',
#   b'24805',
#   b'24804',
#   b'24803',
#   b'24802',
#   b'24800',
#   b'24799',
#   b'24798',
#   b'24796',
#   b'24795',
#   b'24794',
#   b'24793',
#   b'24791',
#   b'24790',
#   b'24789',
#   b'24788',
#   b'24786',
#   b'24785',
#   b'24784',
#   b'24783',
#   b'24781',
#   b'24780',
#   b'24779',
#   b'24778',
#   b'24777',
#   b'24776',
#   b'24775',
#   b'24774',
#   b'24773',
#   b'24772',
#   b'24771',
#   b'24770',
#   b'24769',
#   b'24767',
#   b'24764',
#   b'24763',
#   b'24762',
#   b'24761',
#   b'24760',
#   b'24758',
#   b'24757',
#   b'24756',
#   b'24755',
#   b'24754',
#   b'24753',
#   b'24752',
#   b'24750',
#   b'24749',
#   b'24748',
#   b'24747',
#   b'24746',
#   b'24745',
#   b'24744',
#   b'24743',
#   b'24742',
#   b'24741',
#   b'24740',
#   b'24739',
#   b'24738',
#   b'24737',
#   b'24736',
#   b'24735',
#   b'24734',
#   b'24733',
#   b'24732',
#   b'24731',
#   b'24730',
#   b'24729',
#   b'24728',
#   b'24727',
#   b'24726',
#   b'24725',
#   b'24724',
#   b'24723',
#   b'24722',
#   b'24721',
#   b'24720',
#   b'24719',
#   b'24718',
#   b'24717',
#   b'24716',
#   b'24715',
#   b'24714',
#   b'24713',
#   b'24712',
#   b'24711',
#   b'24710',
#   b'24709',
#   b'24708',
#   b'24707',
#   b'24706',
#   b'24705',
#   b'24704',
#   b'24703',
#   b'24702',
#   b'24701',
#   b'24700',
#   b'24699',
#   b'24698',
#   b'24697',
#   b'24696',
#   b'24695',
#   b'24694',
#   b'24693',
#   b'24692',
#   b'24691',
#   b'24690',
#   b'24689',
#   b'24688',
#   b'24687',
#   b'24686',
#   b'24685',
#   b'24684',
#   b'24683',
#   b'24682',
#   b'24681',
#   b'24680',
#   b'24679',
#   b'24678',
#   b'24677',
#   b'24676',
#   b'24675',
#   b'24674',
#   b'24673',
#   b'24672',
#   b'24671',
#   b'24670',
#   b'24669',
#   b'24668',
#   b'24667',
#   b'24666',
#   b'24665',
#   b'24664',
#   b'24663',
#   b'24662',
#   b'24661',
#   b'24660',
#   b'24659',
#   b'24658',
#   b'24657',
#   b'24656',
#   b'24655',
#   b'24654',
#   b'24653',
#   b'24652',
#   b'24651',
#   b'24650',
#   b'24649',
#   b'24648',
#   b'24647',
#   b'24646',
#   b'24645',
#   b'24644',
#   b'24643',
#   b'24642',
#   b'24641',
#   b'24640',
#   b'24639',
#   b'24638',
#   b'24637',
#   b'24636',
#   b'24635',
#   b'24634',
#   b'24633',
#   b'24632',
#   b'24631',
#   b'24630',
#   b'24629',
#   b'24628',
#   b'24627',
#   b'24626',
#   b'24625',
#   b'24624',
#   b'24623',
#   b'24622',
#   b'24621',
#   b'24620',
#   b'24619',
#   b'24618',
#   b'24617',
#   b'24616',
#   b'24615',
#   b'24614',
#   b'24613',
#   b'24612',
#   b'24611',
#   b'24610',
#   b'24609',
#   b'24608',
#   b'24607',
#   b'24606',
#   b'24605',
#   b'24604',
#   b'24603',
#   b'24602',
#   b'24601',
#   b'24600',
#   b'24599',
#   b'24598',
#   b'24597',
#   b'24596',
#   b'24595',
#   b'24594',
#   b'24593',
#   b'24592',
#   b'24591',
#   b'24590',
#   b'24589',
#   b'24588',
#   b'24587',
#   b'24586',
#   b'24585',
#   b'24584',
#   b'24583',
#   b'24582',
#   b'24581',
#   b'24580',
#   b'24579',
#   b'24578',
#   b'24577',
#   b'24576',
#   b'24575',
#   b'24574',
#   b'24573',
#   b'24572',
#   b'24571',
#   b'24570',
#   b'24569',
#   b'24568',
#   b'24567',
#   b'24566',
#   b'24565',
#   b'24564',
#   b'24563',
#   b'24561',
#   b'24560',
#   b'24558',
#   b'24557',
#   b'24555',
#   b'24554',
#   b'24552',
#   b'24550',
#   b'24548',
#   b'24547',
#   b'24546',
#   b'24544',
#   b'24543',
#   b'24542',
#   b'24541',
#   b'24540',
#   b'24539',
#   b'24538',
#   b'24537',
#   b'24535',
#   b'24534',
#   b'24533',
#   b'24532',
#   b'24531',
#   b'24528',
#   b'24527',
#   b'24526',
#   b'24524',
#   b'24523',
#   b'24522',
#   b'24521',
#   b'24519',
#   b'24517',
#   b'24516',
#   b'24515',
#   b'24511',
#   b'24510',
#   b'24508',
#   b'24506',
#   b'24505',
#   b'24504',
#   b'24503',
#   b'24501',
#   b'24500',
#   b'24498',
#   b'24496',
#   b'24495',
#   b'24494',
#   b'24493',
#   b'24492',
#   b'24490',
#   b'24489',
#   b'24488',
#   b'24487',
#   b'24486',
#   b'24485',
#   b'24483',
#   b'24482',
#   b'24481',
#   b'24480',
#   b'24479',
#   b'24476',
#   b'24474',
#   b'24473',
#   b'24472',
#   b'24470',
#   b'24469',
#   b'24468',
#   b'24467',
#   b'24466',
#   b'24465',
#   b'24464',
#   b'24463',
#   b'24462',
#   b'24461',
#   b'24460',
#   b'24459',
#   b'24458',
#   b'24456',
#   b'24455',
#   b'24454',
#   b'24452',
#   b'24451',
#   b'24449',
#   b'24448',
#   b'24446',
#   b'24445',
#   b'24444',
#   b'24443',
#   b'24441',
#   b'24439',
#   b'24438',
#   b'24437',
#   b'24436',
#   b'24435',
#   b'24434',
#   b'24433',
#   b'24431',
#   b'24430',
#   b'24429',
#   b'24428',
#   b'24427',
#   b'24426',
#   b'24425',
#   b'24424',
#   b'24422',
#   b'24421',
#   b'24419',
#   b'24418',
#   b'24417',
#   b'24416',
#   b'24415',
#   b'24414',
#   b'24413',
#   b'24412',
#   b'24411',
#   b'24410',
#   b'24409',
#   b'24407',
#   b'24406',
#   b'24403',
#   b'24402',
#   b'24400',
#   b'24398',
#   b'24397',
#   b'24396',
#   b'24395',
#   b'24394',
#   b'24393',
#   b'24392',
#   b'24391',
#   b'24390',
#   b'24389',
#   b'24386',
#   b'24383',
#   b'24382',
#   b'24381',
#   b'24380',
#   b'24379',
#   b'24377',
#   b'24376',
#   b'24375',
#   b'24374',
#   b'24373',
#   b'24372',
#   b'24370',
#   b'24369',
#   b'24367',
#   b'24366',
#   b'24365',
#   b'24364',
#   b'24363',
#   b'24361',
#   b'24360',
#   b'24359',
#   b'24358',
#   b'24357',
#   b'24355',
#   b'24354',
#   b'24353',
#   b'24350',
#   b'24349',
#   b'24348',
#   b'24347',
#   b'24346',
#   b'24345',
#   b'24344',
#   b'24342',
#   b'24341',
#   b'24340',
#   b'24339',
#   b'24338',
#   b'24337',
#   b'24336',
#   b'24335',
#   b'24334',
#   b'24332',
#   b'24330',
#   b'24329',
#   b'24328',
#   b'24327',
#   b'24326',
#   b'24325',
#   b'24324',
#   b'24323',
#   b'24322',
#   b'24321',
#   b'24317',
#   b'24312',
#   b'24311',
#   b'24310',
#   b'24309',
#   b'24308',
#   b'24307',
#   b'24306',
#   b'24305',
#   b'24304',
#   b'24303',
#   b'24299',
#   b'24298',
#   b'24297',
#   b'24296',
#   b'24295',
#   b'24294',
#   b'24292',
#   b'24291',
#   b'24290',
#   b'24289',
#   b'24288',
#   b'24287',
#   b'24286',
#   b'24285',
#   b'24284',
#   b'24283',
#   b'24282',
#   b'24280',
#   b'24278',
#   b'24277',
#   b'24276',
#   b'24275',
#   b'24274',
#   b'24273',
#   b'24271',
#   b'24270',
#   b'24269',
#   b'24268',
#   b'24267',
#   b'24265',
#   b'24263',
#   b'24262',
#   b'24261',
#   b'24260',
#   b'24259',
#   b'24258',
#   ...])

# %%
server.logout()

# %%
# r = server.search(None, 'BEFORE', '15-Dec-2020')

# %%
# mids = r[1][0].decode().split(' ')
# for msg_ids_chunk in chunked(mids, 1000):
#     ids = ','.join(msg_ids_chunk)
#     print(len(ids))
#     server.store(ids, '+FLAGS', '\\Deleted')
# server.expunge()
